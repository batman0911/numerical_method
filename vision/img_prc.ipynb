# %%
import numpy as np
import matplotlib.pylab as plt

# %% [markdown]
# read image from file

# %%
img = plt.imread("../data/Lenna.png")

# %% [markdown]
# convert to 256 scale

# %%
im = np.zeros(img.shape, dtype="uint8")
im = img * 256
im = im.astype("uint8")

# %%
print(im)
print(img.shape)
# Out:
# [[[226 137 125]
#   [226 137 125]
#   [223 137 133]
#   ...
#   [230 148 122]
#   [221 130 110]
#   [200  99  90]]
#
#  [[226 137 125]
#   [226 137 125]
#   [223 137 133]
#   ...
#   [230 148 122]
#   [221 130 110]
#   [200  99  90]]
#
#  [[226 137 125]
#   [226 137 125]
#   [223 137 133]
#   ...
#   [230 148 122]
#   [221 130 110]
#   [200  99  90]]
#
#  ...
#
#  [[ 84  18  60]
#   [ 84  18  60]
#   [ 92  27  58]
#   ...
#   [173  73  84]
#   [172  68  76]
#   [177  62  79]]
#
#  [[ 82  22  57]
#   [ 82  22  57]
#   [ 96  32  62]
#   ...
#   [179  70  79]
#   [181  71  81]
#   [185  74  81]]
#
#  [[ 82  22  57]
#   [ 82  22  57]
#   [ 96  32  62]
#   ...
#   [179  70  79]
#   [181  71  81]
#   [185  74  81]]]
# (512, 512, 3)

# %%
rgb_weights = np.array([0.333, 0.333, 0.333])
grayscale_img = np.dot(img[..., :3], rgb_weights)

# %%
grayscale_img.shape
# Out:
# (512, 512)

# %%
plt.imshow(grayscale_img)

# %% [markdown]
# rotate image

# %%
img_90_1 = np.rot90(img, 1)
img_90_2 = np.rot90(img, 2)
img_90_3 = np.rot90(img, 3)

# %%
plt.imshow(img_90_1)

# %% [markdown]
# show image by channel

# %%
fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(15,5))

# axs[0].imshow(img)

for c, ax in zip(range(3), axs):
    tmp_im = np.zeros(im.shape, dtype="uint8")
    tmp_im[:,:,c] = im[:,:,c]
    # print(tmp_im)
    ax.imshow(tmp_im)
    ax.set_axis_off()

# %% [markdown]
# plt.imshow(img[::2,::,::])
# plt.show()

# %%
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(15,5))

axs[0].set_axis_off()
axs[0].imshow(img[::2,::,::])
axs[1].set_axis_off()
axs[1].imshow(img[::,::2,::])

# plt.imshow(img[::2,::,::])
# plt.show()
